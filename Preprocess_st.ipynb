# %% [markdown]
# ## Prepare json files describing train and valid data

# %%
from src.json_generator import generate_json

generate_json("data_st/train_trans.csv", "data_st/wav/uncompressed/wav/train", "./data_st/train_corpus.json")
generate_json("data_st/valid_trans.csv", "data_st/wav/uncompressed/wav/valid", "./data_st/valid_corpus.json")

# %% [markdown]
# ## Remove characters with the same sound

# %%
from src.json_generator import generate_json

remove_redundant("data_st/train_corpus.json")
remove_redundant("data_st/valid_corpus.json")
# Out:
# == Unsupported characters ==
# set()
# == Character stat ==
# ...
